# %%
# !pip install catboost
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB 1.4 MB/s eta 0:00:01
#      -------------------- ------------------- 30.7/61.0 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 406.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
# ...
